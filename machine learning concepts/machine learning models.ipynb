# %% [markdown]
# # Machine learning models
#
# Machine learning is all about modeling
#
# ### Supervised learning
#
# Take an observation and assign a lable to it. and there are two type of supervised learning:
# <ul>
#     <li>Classification</li>
#     <li>Regression</li>
# </ul>
# <br>
# <b>Classification</b>
#
# Assigning to a category to an observation
# <div>
#     <img src="attachment:image.png" width="550" height="500" />
# </div>
# <br>
# <ul>
#     <li>For the above case we consider two <u>features</u> which are High school GPA and Test Result  </li>
#     <li><u>Target</u> variable will be the Accepted and there are two possibilities which are Ture or False</li>
# </ul>
# <br>
# Plotterd observations
# <div>
#     <img src="attachment:image-2.png" width="550" height="500" />
# </div>
# <br>
# Manual Classifier
# <div>
#     <img src="attachment:image-3.png" width="550" height="500" />
# </div>
# Because we are using two features it is easy to classified but if we added more features it will be difficult for human eye
# <ul>
# <li>support vector machine - linear classifier</li>
# <div>
#     <img src="attachment:image-4.png" width="550" height="500" />
# </div>
# <li>support vector machine - polynomial classifier</li>
# <div>
#     <img src="attachment:image-5.png" width="550" height="500" />
# </div>
# </ul>
# <br>
# <b>Regression</b>
#
# Assigning a continuous variable to an observation
# <div>
#     <img src="attachment:image-6.png" width="550" height="500" />
# </div>
# <br>
# <ul>
#     <li>For the above case we consider only one <u>features</u> which is humidity</li>
#     <li><u>Target</u> variable will be the temperature</li>
# </ul>
# <div>
#     <img src="attachment:image-7.png" width="550" height="500" />
# </div>
# Linear regression model to predict the temperature
# <div>
#     <img src="attachment:image-8.png" width="550" height="500" />
# </div>
# <br>
# <ul>
#     <li>Classification = continuous</li>
#     <li>Regression = category</li>
# </ul>
#
#  ### Unsupervised learning
