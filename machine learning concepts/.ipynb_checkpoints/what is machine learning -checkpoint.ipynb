# %% [markdown]
# # What is machine learning
#
# #### AI - a huge set of tools for making computers behave intelligently
# <div>
# <img src="attachment:image-3.png" width="200" height="200"/>
# </div>
#
# #### Machine learning is the most prevalent subset of AI
# <div>
# <img src="attachment:image-2.png" width="215" height="215"/>
# </div>
#
# #### In simply machine learning can be considered as a set of tools for making inferences and predictions from dataul>
# <br>
# use cases of the machine learning
# <ul>
#     <li>predict future events</li>
#     <li>infer patterns</li>
#     <li>infer the causes of events and behaviors</li>
# </ul>
# <br>
# how does it work
# <ul>
#     <li>interdisciplinary mix of statistics and computer science</li>
#     <li>ability to learn without explicitly programmed</li>
#     <li>learn patters from existing data and applies it to new data</li>
#     <li>relies on high-quality data</li>
# </ul>
#
# #### Data science is about making discoveries and creating insights from data
# machine learning is often an important otool for data science work
# <div>
# <img src="attachment:image-4.png" width="215" height="215"/>
# </div>
# <br>
# <b>machine learning moodel</b> - a statistical representation of a real-world process based on data
# <br>
# <br>
# <b>Three types of machine learning</b>
# <ul>
#     <li>Reinforcement learning</li>
#     <li>Supervised learning</li>
#     <li>Unsupervised learning</li>
# </ul>
# <br>
# In Supervised learning and Unsupervised learning the main difference lies in there training data
# <br>
# <ul>
#  <li><b>Training data</b> - existing data to learn from</li>
#  <li><b>Training model</b> - when a model is being built from training data</li>
# </ul>
# <br><br>
# <mark><b>supervised learning training data</b></mark>
# <div>
# <img src="attachment:image-5.png" width="550" height="500" />
# </div>
#
# The above example training data is used to predict the heart disease
# <ul>
#     <li><u>Target variable</u> is the heart disease beacuse it is what we want to predict</li>
#     <li>The values true and false are <u>lables</u> for the target variable lables can be in any format</li>
#     <li>Rows on the table are <u>observation or example</u> in the data set</li>
#     <li>Column headings are known as <u>features</u> and these are different type of information that helps to predict the target</li>
# </ul>
# <br>
# After training the model we can give new input to predict the heart disease
# <div>
#     <img src="attachment:image-6.png" width="550" height="500" />
# </div>
# <br>
# In supervised learning we training data is "labeled" and in unsupervised learning we only have features and it is used for work such as
# <ul>
# <li>Anomaly detection</li>
# <li>Clustering</li>
# </ul>
# <mark><b>unsupervised learning training data</b></mark>
# <div>
# <img src="attachment:image-7.png" width="550" height="500" />
# </div>
# <br>
# We can passed the data into a clustering model and get categorize based on feature similarity
# <div>
# <img src="attachment:image-8.png" width="450" height="300" />
# </div>
# <br>
# After training the model we can give new input to check which category the patient falls
# <div>
#     <img src="attachment:image-9.png" width="550" height="500" />
# </div>
#
# #
# <ul>
# <li>
# In reality the data dosen't always come with labels and it requires manual labor to label
# </li>
# </ul>
#
# ### Machine learning workflow
#
# <ul>
#     <li>Step 1: Extract features</li>
#     <br>
#     <li>Step 2: Split dataset into two categories
#         <ul>
#             <li>Train dataset</li>
#             <li>Test dataset</li>
#         </ul>
#     </li>
#     <br>
#     <li>Step 3: Train the model using train data
#         <div>
#             <img src="attachment:image-10.png" width="450" height="300" />
#         </div>
#     </li>
#     <br>
#     <li>Step 4: Evaluate the model using test data</li>
#         If the preformance of the model is ok then it is ready to use else we need to <u>tune</u> (re-train)the model
# </ul>
